# %% [markdown]
# # Wedding Matching
#
# This project/code was started because we wanted to make sure that people were encouraged to mingle at our wedding. We are the only common links between everyone there and some people have remarkable obscure but meaningful connections (Astrophysics! Trains! Obsession with Officious Women!). The intention was to pop a couple of interesting conversation starters on each person's table setting. The ideal number would be 2-4, but trying to ensure that every one of 80 guests has that number of connections was proving time consuming in person.
#
# Hence, the tech bros strike again with another overengineered solution to a problem of their own making.
#
# Enjoy!

# %% [markdown]
# ## Defining Our Guests
#
# We represent connections between our guests as a graph. Nodes are parties (i.e. people invited to our wedding) and Edges are matches (i.e. connections between two people). We also furnish the matches with two pieces of metadata:
# * The reason behind that connection
# * Whether or not we force the matching to accept it (i.e. because we think it is a particularly funny or witty connection).
#
# Note that this is PII, so should be removed/anonymised, obfuscated before it is shared.

# %%
import networkx as nx
import matplotlib.pyplot as plt

def ap(G, person1, person2, reason, forced=False):
    G.add_edges_from([
      (person1, person2, {"why": reason, "forced": forced})
    ])

def generate_full_graph():
    graph = nx.Graph()
    people = ['Person 0', 'Person 1', 'Person 2', 'Person 3', 'Person 4', 'Person 5', 'Person 6', 'Person 7', 'Person 8', 'Person 9', 'Person 10', 'Person 11', 'Person 12', 'Person 13', 'Person 14', 'Person 15', 'Person 16', 'Person 17', 'Person 18', 'Person 19', 'Person 20', 'Person 21', 'Person 22', 'Person 23', 'Person 24', 'Person 25', 'Person 26', 'Person 27', 'Person 28', 'Person 29', 'Person 30', 'Person 31', 'Person 32', 'Person 33', 'Person 34', 'Person 35', 'Person 36', 'Person 37', 'Person 38', 'Person 39', 'Person 40', 'Person 41', 'Person 42', 'Person 43', 'Person 44', 'Person 45', 'Person 46', 'Person 47', 'Person 48', 'Person 49', 'Person 50', 'Person 51', 'Person 52', 'Person 53', 'Person 54', 'Person 55', 'Person 56', 'Person 57', 'Person 58', 'Person 59', 'Person 60', 'Person 61', 'Person 62', 'Person 63', 'Person 64', 'Person 65', 'Person 66', 'Person 67', 'Person 68', 'Person 69', 'Person 70', 'Person 71', 'Person 72', 'Person 73']
    
    graph.add_nodes_from(people)

    ap(graph, "Person 0", "Person 19", "Nursing")
    ap(graph, "Person 0", "Person 23", "Scots in England")
    ap(graph, "Person 0", "Person 25", "Musicals")
    ap(graph, "Person 0", "Person 20", "Musicals")
    ap(graph, "Person 25", "Person 20", "Musicals")
    ap(graph, "Person 1", "Person 54", "Manchester")
    ap(graph, "Person 1", "Person 6", "Bob Dylan", forced=True)
    ap(graph, "Person 1", "Person 59", "Trains")
    ap(graph, "Person 2", "Person 21", "Teaching")
    ap(graph, "Person 2", "Person 22", "Reality TV")
    ap(graph, "Person 2", "Person 22", "Winnie the Pooh")
    ap(graph, "Person 5", "Person 26", "Inverness")
    ap(graph, "Person 5", "Person 25", "Inverness")
    ap(graph, "Person 5", "Person 30", "Folk Music")
    ap(graph, "Person 6", "Person 22", "Podcasting")
    ap(graph, "Person 6", "Person 22", "Comedy & Edinburgh", forced=True)
    ap(graph, "Person 6", "Person 62", "Maths!")
    ap(graph, "Person 6", "Person 44", "D&D")
    ap(graph, "Person 7", "Person 37", "Video Games")
    ap(graph, "Person 7", "Person 27", "Edinburgh")
    ap(graph, "Person 7", "Person 70", "UX")
    ap(graph, "Person 8", "Person 72", "Berlin")
    ap(graph, "Person 8", "Person 73", "Berlin")
    ap(graph, "Person 8", "Person 63", "Berlin")
    ap(graph, "Person 8", "Person 44", "Birmingham")
    ap(graph, "Person 8", "Person 11", "Birmingham")
    ap(graph, "Person 9", "Person 42", "Social Services", forced=True)
    ap(graph, "Person 9", "Person 65", "Reality TV")
    ap(graph, "Person 9", "Person 22", "Reality TV")
    ap(graph, "Person 10", "Person 54", "Manchester Tescos")
    ap(graph, "Person 11", "Person 38", "Birmingham Universities")
    ap(graph, "Person 11", "Person 50", "Allotments")
    ap(graph, "Person 11", "Person 51", "Allotments")
    ap(graph, "Person 17", "Person 11", "Stoke")
    ap(graph, "Person 12", "Person 41", "Oasis")
    ap(graph, "Person 12", "Person 42", "Criminology")
    ap(graph, "Person 12", "Person 22", "Mud Run")
    ap(graph, "Person 13", "Person 22", "Mud Run")
    ap(graph, "Person 16", "Person 21", "Teaching")
    ap(graph, "Person 16", "Person 50", "Spanish Holidays")
    ap(graph, "Person 16", "Person 51", "Spanish Holidays")
    ap(graph, "Person 16", "Person 0", "Grandparents")
    ap(graph, "Person 16", "Person 1", "Grandparents")
    ap(graph, "Person 16", "Person 5", "Grandparents")
    ap(graph, "Person 16", "Person 41", "Table Tennis")
    ap(graph, "Person 16", "Person 30", "Pub Quiz Etiquette", forced=True)
    ap(graph, "Person 17", "Person 50", "Spanish Holidays")
    ap(graph, "Person 17", "Person 51", "Spanish Holidays")
    ap(graph, "Person 17", "Person 56", "Veggie")
    ap(graph, "Person 17", "Person 63", "Veggie")
    ap(graph, "Person 17", "Person 64", "Veggie")
    ap(graph, "Person 63", "Person 56", "Veggie")
    ap(graph, "Person 64", "Person 56", "Veggie")
    ap(graph, "Person 18", "Person 22", "Instrumentalists")
    ap(graph, "Person 18", "Person 43", "California")
    ap(graph, "Person 18", "Person 73", "California")
    ap(graph, "Person 20", "Person 43", "California", forced=True)
    ap(graph, "Person 20", "Person 73", "California")
    ap(graph, "Person 19", "Person 53", "Nursing")
    ap(graph, "Person 20", "Person 25", "Musicals")
    ap(graph, "Person 20", "Person 54", "Musicals")
    ap(graph, "Person 20", "Person 0", "Musicals")
    ap(graph, "Person 20", "Person 45", "Musicals")
    ap(graph, "Person 25", "Person 45", "Musicals")
    ap(graph, "Person 9", "Person 20", "Weird Dogs")
    ap(graph, "Person 21", "Person 50", "Dating as a gay man")
    ap(graph, "Person 71", "Person 21", "Horror Movies")
    ap(graph, "Person 23", "Person 41", "Sporty", forced=True)
    ap(graph, "Person 23", "Person 14", "Stoke Clubbing", forced=True)
    ap(graph, "Person 25", "Person 65", "Female Crushes", forced=True)
    ap(graph, "Person 26", "Person 63", "Maths and stuff")
    ap(graph, "Person 26", "Person 62", "Maths and stuff")
    ap(graph, "Person 27", "Person 60", "Doctors")
    ap(graph, "Person 28", "Person 63", "Board Games")
    ap(graph, "Person 28", "Person 6", "Board Games")
    ap(graph, "Person 28", "Person 70", "Board Games")
    ap(graph, "Person 28", "Person 49", "Board Games")
    ap(graph, "Person 63", "Person 6", "Board Games")
    ap(graph, "Person 63", "Person 70", "Board Games")
    ap(graph, "Person 63", "Person 49", "Board Games", forced=True)
    ap(graph, "Person 6", "Person 70", "Board Games")
    ap(graph, "Person 6", "Person 49", "Board Games")
    ap(graph, "Person 70", "Person 49", "Board Games")
    ap(graph, "Person 28", "Person 50", "LGBT Acadaemia")
    ap(graph, "Person 28", "Person 50", "Improv", forced=True)
    ap(graph, "Person 6", "Person 50", "Improv")
    ap(graph, "Person 29", "Person 46", "US Healthcare")
    ap(graph, "Person 29", "Person 0", "Mindless Games")
    ap(graph, "Person 31", "Person 62", "Bristol")
    ap(graph, "Person 31", "Person 60", "Doctors")
    ap(graph, "Person 31", "Person 6", "Long Distance Relationships")
    ap(graph, "Person 32", "Person 58", "Interfaith LGBT")
    ap(graph, "Person 32", "Person 52", "Swing Dancing")
    ap(graph, "Person 34", "Person 11", "Leg Injuries")
    ap(graph, "Person 36", "Person 0", "Cruising")
    ap(graph, "Person 36", "Person 57", "Music in HE")
    ap(graph, "Person 40", "Person 61", "Being Gay in the Middle East")
    ap(graph, "Person 41", "Person 55", "Liverpool")
    ap(graph, "Person 42", "Person 21", "Southampton Uni")
    ap(graph, "Person 43", "Person 73", "Californians Abroard", forced=True)
    ap(graph, "Person 43", "Person 70", "Being good humans", forced=True)
    ap(graph, "Person 44", "Person 47", "Working out")
    ap(graph, "Person 45", "Person 52", "Immersive Art")
    ap(graph, "Person 45", "Person 64", "East Europe")
    ap(graph, "Person 46", "Person 43", "Anti-B-Dubz")
    ap(graph, "Person 48", "Person 18", "Bands")
    ap(graph, "Person 48", "Person 22", "Brass Bands")
    ap(graph, "Person 48", "Person 43", "Healthcare Comms")
    ap(graph, "Person 51", "Person 29", "Arsenal")
    ap(graph, "Person 52", "Person 33", "Wine")
    ap(graph, "Person 54", "Person 0", "Les Miserables", forced=True)
    ap(graph, "Person 55", "Person 52", "Foodie")
    ap(graph, "Person 58", "Person 52", "Foodie")
    ap(graph, "Person 58", "Person 55", "Foodie")
    ap(graph, "Person 56", "Person 63", "Lib Dems")
    ap(graph, "Person 56", "Person 70", "Live Music")
    ap(graph, "Person 56", "Person 6", "Deep South")
    ap(graph, "Person 57", "Person 68", "Functional Programming")
    ap(graph, "Person 57", "Person 22", "Podcasting")
    ap(graph, "Person 57", "Person 67", "Podcasting")
    ap(graph, "Person 67", "Person 22", "Podcasting")
    ap(graph, "Person 57", "Person 62", "Bristol")
    ap(graph, "Person 57", "Person 31", "Bristol")
    ap(graph, "Person 59", "Person 13", "Yorkshire")
    ap(graph, "Person 59", "Person 12", "Yorkshire")
    ap(graph, "Person 59", "Person 26", "Planes")
    ap(graph, "Person 60", "Person 53", "Psych")
    ap(graph, "Person 60", "Person 63", "Sci-Fi")
    ap(graph, "Person 62", "Person 27", "Australia")
    ap(graph, "Person 62", "Person 68", "Maths Geekery")
    ap(graph, "Person 62", "Person 63", "Maths Geekery")
    ap(graph, "Person 62", "Person 63", "Oxford")
    ap(graph, "Person 63", "Person 59", "Catz Alumni", forced=True)
    ap(graph, "Person 63", "Person 38", "Isle of Wight")
    ap(graph, "Person 63", "Person 2", "Isle of Wight")
    ap(graph, "Person 38", "Person 2", "Isle of Wight")
    ap(graph, "Person 63", "Person 44", "Astrophysics")
    ap(graph, "Person 65", "Person 59", "Trains")
    ap(graph, "Person 65", "Person 70", "Trains")
    ap(graph, "Person 70", "Person 59", "Trains")
    ap(graph, "Person 66", "Person 46", "Marvel")
    ap(graph, "Person 67", "Person 60", "Baking")
    ap(graph, "Person 69", "Person 22", "Reupholstery")
    ap(graph, "Person 69", "Person 59", "Preventing Train Crashes")
    ap(graph, "Person 69", "Person 7", "Animation & Graphics")
    ap(graph, "Person 69", "Person 73", "Animation & Graphics")
    ap(graph, "Person 71", "Person 70", "PhDs at Birmingham")
    ap(graph, "Person 71", "Person 28", "Charity History")
    ap(graph, "Person 71", "Person 43", "Charity History")
    ap(graph, "Person 72", "Person 63", "Berlin")
    ap(graph, "Person 72", "Person 70", "XTreme Dance")
    ap(graph, "Person 72", "Person 34", "Squat Parties")

    return graph

graph = generate_full_graph()

# %% [markdown]
# We can plot the parties and connections between them using matplotlib. We avoid plotting the topics for reasons of space/readability

# %%
def plot_graph(graph):
    fig, ax = plt.subplots(1,1, figsize=(20,20))

    nx.draw_networkx(
        graph,
        pos=nx.spring_layout(graph),
        node_size=40,
        show_labels=False,
        ax = ax,
        )
    
plot_graph(graph)

# %% [markdown]
# ## Loser Detection
#
# We have to make sure there are no losers at our wedding. (More accurately: We need to understand who we need more information about to make this hare-brained scheme work.)
#
# We remove people who are unlikely to have many - if any - connections for two main reasons.
# * They act as outliers on the plot and squash the interesting bit of data in the middle
# * They will never be fully matched and therefore we don't want to algorithms developed to spend a lot of time pandering to them.
#
# This is outputted and we do need to act on this information - but the solution to this problem involves talking to people and Python does not have a library for that --- *yet*.
#
# For our purposes, a party is a loser if we only understand one interesting thing about them - even if it would connect them to multiple people.

# %%
def matches_containing_party(G, party):
    return [match for match in G.edges(data="why") if party in match]

def reasons_for_matches(G, party):
    return set([match[2] for match in matches_containing_party(G, party)])

#A loser is anyone who has only one thing interesting about them
def losers(G):
    return [party for party in G.nodes if len(reasons_for_matches(G, party)) < 2]
    
def remove_losers(G):
    print("Removing %s" % losers(G))
    G.remove_nodes_from(losers(G))

remove_losers(graph)

plot_graph(graph)
plt.show()
# Out:
# Removing ['Person 3', 'Person 4', 'Person 10', 'Person 14', 'Person 15', 'Person 19', 'Person 24', 'Person 33', 'Person 35', 'Person 37', 'Person 39', 'Person 40', 'Person 47', 'Person 49', 'Person 61', 'Person 66']

# %% [markdown]
# Support functions. These are largely uninteresting.

# %%
#It cannot be added if the reason overlaps with any existing reason two parties are connected
def match_can_be_added(matching_graph, match):
    reasons_for_start = reasons_for_matches(matching_graph, match[0])
    reasons_for_end = reasons_for_matches(matching_graph, match[1])
    
    return (match[2] not in reasons_for_start) & (match[2] not in reasons_for_end)

def potential_matches_for_party(matching_graph, connection_graph, party):
    return [match for match in matches_containing_party(connection_graph, party) if match_can_be_added(matching_graph, match)]

def least_matched_parties_with_outstanding_matches(matching_graph, connection_graph):
    parties_with_outstanding_matches = [party for party in connection_graph.nodes if len(potential_matches_for_party(matching_graph, connection_graph, party)) > 0]
    lowest_degree = min([degree for (node, degree) in matching_graph.degree if node in parties_with_outstanding_matches])
    return [party for (party, degree) in matching_graph.degree if (party in parties_with_outstanding_matches) & (degree == lowest_degree)]

def other_end_of_match(match, party):
    if(match[0] == party):
        return match[1]
    else:
        return match[0]

# %% [markdown]
# ## The Algorithm
#
# The algorithm will iteratively move matches from the raw "Connections Graph" where we store the original connection to the "Matching Graph". The ulimtate aim is to have every node in the matching graph be of degree 2 with every connection/match/edge being for a different facet of a person. That's a lot of work so getting close is good enough.
#
# The approach:
# * Given our Connections Graph G = (V, E).
# * __Step 1__: Construct a blank matching graph S = (V, {})
# * __Step 2__: For each 'forced' match, remove that match from E and add it to the edge set of S.
# * __Step 3__: Determine whether we are ready to terminate - the condition for this is that every party with less than two matches (degree < 2 on the matching graph S) cannot be matched further (for party P, all edges (P,Q) on the connections graph G would lead to a match for a duplicate reason for either party P or Q).
# * __Step 4__: If we did not terminate, we migrate an edge from the connections graph to the matching graph.
#     * __Step 4a__: Select a party to match. From among the nodes on the matching graph with the lowest degree; select the one that also has the lowest degree on the connections graph. If there is a tie, choose arbitrarily.
#     * __Step 4b__: Select a match adjacent to that party. From among the matches (P, Q) choose the one whose destination Q has the lowest degree on the matching graph. If there is a tie, choose arbitrarily
#     * __Step 4c__: Remove that edge from the edge set of G. Add it to the edgeset of S.
# * __Step 5__: Return to __Step 3__ to determine whether we terminate again.

# %%
# Step 2 of Algorithm
def add_forced_matches(matching_graph, connection_graph):
    edges = [(edge[0], edge[1], {"why": edge[2]["why"]}) for edge in connection_graph.edges(data=True) if edge[2]["forced"]]
    matching_graph.add_edges_from(edges)
    fresh_graph.remove_edges_from(edges)

#Step 3 of Algorithm
def unmatched_people_have_further_mappings(matching_graph, connection_graph):
    unmatched_parties = [party for (party, degree) in matching_graph.degree if degree < 2]
    return any([len(potential_matches_for_party(matching_graph, connection_graph, party)) > 0 for party in unmatched_parties])

# Step 4a of Algorithm
#Of all parties with the least existing matches, select the most isolated one
def next_party_to_match(matching_graph, connection_graph):
    most_available_parties = least_matched_parties_with_outstanding_matches(matching_graph, connection_graph)
    outstanding_match_degrees = connection_graph.degree
    
    parties_with_degrees = [(party, outstanding_match_degrees[party]) for party in most_available_parties]
    
    lowest_degree = min([d[1] for d in parties_with_degrees])
    candidates = [party for party in parties_with_degrees if party[1] == lowest_degree]
    return candidates[0][0] #select an arbitrary party

#Step 4b of Algorithm
#Select the match that is with the most isolated party
def next_match_for_party(matching_graph, connection_graph, party):
    all_matches_for_party = potential_matches_for_party(matching_graph, connection_graph, party)
    
    existing_matchings = matching_graph.degree
    matches_with_destination_degrees = [(edge, existing_matchings[other_end_of_match(edge, party)]) for edge in all_matches_for_party]
    least_degree = min([d[1] for d in matches_with_destination_degrees])
    
    candidates = [match for match in matches_with_destination_degrees if match[1] == least_degree]
    selected_match = candidates[0][0] #select an arbitrary match
    return (selected_match[0], selected_match[1], {"why": selected_match[2]})

#Step 4c of Algorithm
def perform_match(matching_graph, connection_graph, match):
    matching_graph.add_edges_from([match])
    fresh_graph.remove_edges_from([match])

# %%
#Execute the algorithm and plot the accompanying matching graph
fresh_graph = generate_full_graph()
remove_losers(fresh_graph)

matching_graph = nx.Graph()
matching_graph.add_nodes_from(fresh_graph.nodes)
add_forced_matches(matching_graph, fresh_graph)

while unmatched_people_have_further_mappings(matching_graph, fresh_graph):
    party = next_party_to_match(matching_graph, fresh_graph)
    match = next_match_for_party(matching_graph, fresh_graph, party)
    perform_match(matching_graph, fresh_graph, match)
        
plot_graph(matching_graph)
plt.show()
# Out:
# Removing ['Person 3', 'Person 4', 'Person 10', 'Person 14', 'Person 15', 'Person 19', 'Person 24', 'Person 33', 'Person 35', 'Person 37', 'Person 39', 'Person 40', 'Person 47', 'Person 49', 'Person 61', 'Person 66']

# %% [markdown]
# Output everyone's common interests as a CSV for the purposes of mail merging onto place settings later.

# %%
def who_am_i_matched_with(matching_graph, party):
    return [(other_end_of_match(match, party), match[2]) for match in matches_containing_party(matching_graph, party)]

def pretty_print(match):
    return "You should speak to %s about %s" % match

for party in matching_graph.nodes:
    output = "\"%s\"" % party
    for m in who_am_i_matched_with(matching_graph, party):
        output = output + ",\"%s\"" % pretty_print(m)
    print(output)
# Out:
# "Person 0","You should speak to Person 54 about Les Miserables","You should speak to Person 23 about Scots in England","You should speak to Person 36 about Cruising","You should speak to Person 25 about Musicals"
# "Person 1","You should speak to Person 6 about Bob Dylan","You should speak to Person 54 about Manchester","You should speak to Person 16 about Grandparents"
# "Person 2","You should speak to Person 38 about Isle of Wight","You should speak to Person 21 about Teaching"
# "Person 5","You should speak to Person 26 about Inverness","You should speak to Person 30 about Folk Music"
# "Person 6","You should speak to Person 1 about Bob Dylan","You should speak to Person 22 about Comedy & Edinburgh","You should speak to Person 44 about D&D","You should speak to Person 31 about Long Distance Relationships"
# "Person 7","You should speak to Person 27 about Edinburgh","You should speak to Person 69 about Animation & Graphics"
# ...
